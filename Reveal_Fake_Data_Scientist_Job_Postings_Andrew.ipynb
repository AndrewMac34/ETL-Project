# %%
import pandas as pd
import os
import string
import numpy

# %%
fake_jobs_pd = pd.read_csv("data_source/fake_job_postings.csv")

# %%
fake_jobs_pd=fake_jobs_pd.rename_axis('job_key')
fake_jobs_pd.head()
# Out:
#          job_id                                      title  \
# job_key
# 0             1                           Marketing Intern
# 1             2  Customer Service - Cloud Video Production
# 2             3    Commissioning Machinery Assistant (CMA)
# 3             4          Account Executive - Washington DC
# 4             5                        Bill Review Manager
#
#                    location department salary_range  \
# job_key
# 0          US, NY, New York  Marketing          NaN
# 1            NZ, , Auckland    Success          NaN
# 2             US, IA, Wever        NaN          NaN
# 3        US, DC, Washington      Sales          NaN
# 4        US, FL, Fort Worth        NaN          NaN
#
#                                            company_profile  \
# job_key
# 0        We're Food52, and we've created a groundbreaki...
# 1        90 Seconds, the worlds Cloud Video Production ...
# 2        Valor Services provides Workforce Solutions th...
# 3        Our passion for improving quality of life thro...
# 4        SpotSource Solutions LLC is a Global Human Cap...
#
#                                                description  \
# job_key
# 0        Food52, a fast-growing, James Beard Award-winn...
# 1        Organised - Focused - Vibrant - Awesome!Do you...
# 2        Our client, located in Houston, is actively se...
# 3        THE COMPANY: ESRI – Environmental Systems Rese...
# 4        JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                               requirements  \
# job_key
# 0        Experience with content management systems a m...
# 1        What we expect from you:Your key responsibilit...
# 2        Implement pre-commissioning and commissioning ...
# 3        EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4        QUALIFICATIONS:RN license in the State of Texa...
#
#                                                   benefits  telecommuting  \
# job_key
# 0                                                      NaN              0
# 1        What you will get from usThrough being part of...              0
# 2                                                      NaN              0
# 3        Our culture is anything but corporate—we have ...              0
# 4                                    Full Benefits Offered              0
#
#          has_company_logo  has_questions employment_type required_experience  \
# job_key
# 0                       1              0           Other          Internship
# 1                       1              0       Full-time      Not Applicable
# 2                       1              0             NaN                 NaN
# 3                       1              0       Full-time    Mid-Senior level
# 4                       1              1       Full-time    Mid-Senior level
#
#         required_education                   industry              function  \
# job_key
# 0                      NaN                        NaN             Marketing
# 1                      NaN  Marketing and Advertising      Customer Service
# 2                      NaN                        NaN                   NaN
# 3        Bachelor's Degree          Computer Software                 Sales
# 4        Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#          fraudulent
# job_key
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
ci_st_co=fake_jobs_pd['location'].tolist()

print(type(ci_st_co))
cou=[]
sta=[]
cit=[]


for i in ci_st_co:
        #print(i)
    try:
        co=i.split(', ')
    
        cou.append(co[0])
        sta.append(co[1])
        cit.append(co[2])
        
    except:
        
        cou.append('')
        sta.append('')
        cit.append('')
print(len(cou))
# Out:
# <class 'list'>
# 17974

# %%
print(len(cou))
print(len(sta))
print(len(cit))
k=len(cou)
while k>len(cit):
    
    del cou[-1]
    k=k-1
    print(len(cou))
#print(len(cou))
# Out:
# 17974
# 17880
# 17880
# 17973
# 17972
# 17971
# 17970
# 17969
# 17968
# 17967
# 17966
# 17965
# 17964
# 17963
# 17962
# 17961
# 17960
# 17959
# 17958
# 17957
# 17956
# 17955
# 17954
# 17953
# 17952
# 17951
# 17950
# 17949
# 17948
# 17947
# 17946
# 17945
# 17944
# 17943
# 17942
# 17941
# 17940
# 17939
# 17938
# 17937
# 17936
# 17935
# 17934
# 17933
# 17932
# 17931
# 17930
# 17929
# 17928
# 17927
# 17926
# 17925
# 17924
# 17923
# 17922
# 17921
# 17920
# 17919
# 17918
# 17917
# 17916
# 17915
# 17914
# 17913
# 17912
# 17911
# 17910
# 17909
# 17908
# 17907
# 17906
# 17905
# 17904
# 17903
# 17902
# 17901
# 17900
# 17899
# 17898
# 17897
# 17896
# 17895
# 17894
# 17893
# 17892
# 17891
# 17890
# 17889
# 17888
# 17887
# 17886
# 17885
# 17884
# 17883
# 17882
# 17881
# 17880

# %%
datas={'country':cou,
       'state':sta,
       'city':cit }   
uplocs=pd.DataFrame(datas)
print(len(datas['country']))
uplocs.head()
# Out:
# 17880
#   country state        city
# 0      US    NY    New York
# 1      NZ          Auckland
# 2      US    IA       Wever
# 3      US    DC  Washington
# 4      US    FL  Fort Worth

# %%
fake_job_drops=['salary_range','company_profile','benefits','telecommuting',\
               'has_company_logo','has_questions']

updated_fake_jobs_pd=fake_jobs_pd
#try:
for cols in fake_job_drops:
    updated_fake_jobs_pd=updated_fake_jobs_pd.drop(f'{cols}',1)
    #updated_fake_jobs_pd.head()
#except:
        #updated_ds_jobs_pd.head()
print(len(updated_fake_jobs_pd))
updated_fake_jobs_pd.head()
# Out:
# 17880
#          job_id                                      title  \
# job_key
# 0             1                           Marketing Intern
# 1             2  Customer Service - Cloud Video Production
# 2             3    Commissioning Machinery Assistant (CMA)
# 3             4          Account Executive - Washington DC
# 4             5                        Bill Review Manager
#
#                    location department  \
# job_key
# 0          US, NY, New York  Marketing
# 1            NZ, , Auckland    Success
# 2             US, IA, Wever        NaN
# 3        US, DC, Washington      Sales
# 4        US, FL, Fort Worth        NaN
#
#                                                description  \
# job_key
# 0        Food52, a fast-growing, James Beard Award-winn...
# 1        Organised - Focused - Vibrant - Awesome!Do you...
# 2        Our client, located in Houston, is actively se...
# 3        THE COMPANY: ESRI – Environmental Systems Rese...
# 4        JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                               requirements employment_type  \
# job_key
# 0        Experience with content management systems a m...           Other
# 1        What we expect from you:Your key responsibilit...       Full-time
# 2        Implement pre-commissioning and commissioning ...             NaN
# 3        EDUCATION: Bachelor’s or Master’s in GIS, busi...       Full-time
# 4        QUALIFICATIONS:RN license in the State of Texa...       Full-time
#
#         required_experience required_education                   industry  \
# job_key
# 0                Internship                NaN                        NaN
# 1            Not Applicable                NaN  Marketing and Advertising
# 2                       NaN                NaN                        NaN
# 3          Mid-Senior level  Bachelor's Degree          Computer Software
# 4          Mid-Senior level  Bachelor's Degree     Hospital & Health Care
#
#                      function  fraudulent
# job_key
# 0                   Marketing           0
# 1            Customer Service           0
# 2                         NaN           0
# 3                       Sales           0
# 4        Health Care Provider           0

# %%
cleanfakes=updated_fake_jobs_pd.join(uplocs)
cleanfakes.to_csv('cleaned fake jobs.csv')

# %%
ds_jobs_pd = pd.read_csv("data_source/data_scientist_united_states_job_postings_jobspikr.csv")

# %%
ds_jobs_pd=ds_jobs_pd.rename_axis('ds_key')
ds_jobs_pd.head()
#len(ds_jobs_pd['url'])
# Out:
#                   crawl_timestamp  \
# ds_key
# 0       2019-02-06 05:26:22 +0000
# 1       2019-02-06 05:33:41 +0000
# 2       2019-02-06 05:33:35 +0000
# 3       2019-02-06 05:33:42 +0000
# 4       2019-02-06 05:48:23 +0000
#
#                                                       url  \
# ds_key
# 0       https://www.indeed.com/viewjob?jk=fd83355c2b23...
# 1       https://www.dice.com/jobs/detail/Data-Scientis...
# 2       https://www.dice.com/jobs/detail/Data-Scientis...
# 3       https://www.indeed.com/viewjob?jk=841edd86ead2...
# 4       https://job-openings.monster.com/senior-data-s...
#
#                                                 job_title            category  \
# ds_key
# 0                             Enterprise Data Scientist I  Accounting/Finance
# 1                                          Data Scientist                 NaN
# 2                                          Data Scientist                 NaN
# 3       Data Scientist, Aladdin Wealth Tech, Associate...  Accounting/Finance
# 4                                   Senior Data Scientist             biotech
#
#                                 company_name            city  \
# ds_key
# 0                    Farmers Insurance Group  Woodland Hills
# 1                             Luxoft USA Inc      Middletown
# 2       Cincinnati Bell Technology Solutions        New York
# 3                                  BlackRock        New York
# 4                                CyberCoders       Charlotte
#
#                           state country   inferred_city  inferred_state  ...  \
# ds_key                                                                   ...
# 0                            CA     Usa  Woodland hills      California  ...
# 1                            NJ     Usa      Middletown      New jersey  ...
# 2                            NY     Usa        New york        New york  ...
# 3       NY 10055 (Midtown area)     Usa        New york        New york  ...
# 4                            NC     Usa       Charlotte  North carolina  ...
#
#                                           job_description   job_type  \
# ds_key
# 0       Read what people are saying about working here...  Undefined
# 1       We have an immediate opening for a Sharp Data ...  Undefined
# 2       Candidates should have the following backgroun...  Full Time
# 3       Read what people are saying about working here...  Undefined
# 4       We are seeking an extraordinary Data Scientist...  Full Time
#
#        salary_offered job_board  geo            cursor contact_email  \
# ds_key
# 0                 NaN    indeed  usa  1549432819114777           NaN
# 1                 NaN      dice  usa  1549432819122106           NaN
# 2                 NaN      dice  usa  1549432819236156           NaN
# 3                 NaN    indeed  usa  1549432819259473           NaN
# 4                 NaN   monster  usa  1549436429015957           NaN
#
#         contact_phone_number                           uniq_id  \
# ds_key
# 0                        NaN  3b6c6acfcba6135a31c83bd7ea493b18
# 1                        NaN  741727428839ae7ada852eebef29b0fe
# 2                        NaN  cdc9ef9a1de327ccdc19cc0d07dbbb37
# 3                        NaN  1c8541cd2c2c924f9391c7d3f526f64e
# 4                        NaN  445652a560a5441060857853cf267470
#
#        html_job_description
# ds_key
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 22 columns]

# %%
drops=['crawl_timestamp','url','company_name','inferred_city','inferred_state','inferred_country',\
    'salary_offered','job_board','geo','cursor','contact_email','contact_phone_number',\
       'uniq_id','html_job_description','post_date']

updated_ds_jobs_pd=ds_jobs_pd
#try:
for item in drops:
    updated_ds_jobs_pd=updated_ds_jobs_pd.drop(f'{item}',1)
    updated_ds_jobs_pd.head()
#except:
        #updated_ds_jobs_pd.head()
updated_ds_jobs_pd.to_csv("cleaned data science jobs.csv")
updated_ds_jobs_pd.head()
# Out:
#                                                 job_title            category  \
# ds_key
# 0                             Enterprise Data Scientist I  Accounting/Finance
# 1                                          Data Scientist                 NaN
# 2                                          Data Scientist                 NaN
# 3       Data Scientist, Aladdin Wealth Tech, Associate...  Accounting/Finance
# 4                                   Senior Data Scientist             biotech
#
#                   city                    state country  \
# ds_key
# 0       Woodland Hills                       CA     Usa
# 1           Middletown                       NJ     Usa
# 2             New York                       NY     Usa
# 3             New York  NY 10055 (Midtown area)     Usa
# 4            Charlotte                       NC     Usa
#
#                                           job_description   job_type
# ds_key
# 0       Read what people are saying about working here...  Undefined
# 1       We have an immediate opening for a Sharp Data ...  Undefined
# 2       Candidates should have the following backgroun...  Full Time
# 3       Read what people are saying about working here...  Undefined
# 4       We are seeking an extraordinary Data Scientist...  Full Time

# %%
#Get only Fraud records
#fake_jobs = pd.DataFrame(["fraudulent"],index = ["fraudulent"], columns=["fraudulent"])
if fake_jobs_pd.index.name != 'fraudulent':
   fake_jobs_pd.set_index("fraudulent", inplace = True)
fake_jobs = fake_jobs_pd.loc[1]
fake_jobs
# Out:
#             job_id                                       title  \
# fraudulent
# 1               99                             IC&E Technician
# 1              145                                Forward Cap.
# 1              174           Technician Instrument & Controls
# 1              181                             Sales Executive
# 1              216                     IC&E Technician Mt Poso
# ...            ...                                         ...
# 1            17828  Student Positions Part-Time and Full-Time.
# 1            17829                             Sales Associate
# 1            17830                           Android Developer
# 1            17831                              Payroll Clerk
# 1            17832                             Furniture mover
#
#                                       location            department  \
# fraudulent
# 1                            US, , Stocton, CA          Oil & Energy
# 1                                          NaN                   NaN
# 1                                           US  Power Plant & Energy
# 1                              PK, SD, Karachi                 Sales
# 1           US, CA, Bakersfield, CA / Mt. Poso          Oil & Energy
# ...                                        ...                   ...
# 1                          US, CA, Los Angeles                   NaN
# 1                              AU, NSW, Sydney   Sales and Marketing
# 1                               PL, MZ, Warsaw                   NaN
# 1                             US, NY, New York                   NaN
# 1                              US, IL, Chicago                   NaN
#
#             salary_range                                    company_profile  \
# fraudulent
# 1           95000-115000                                                ...
# 1                    NaN                                                NaN
# 1                    NaN  Edison International and Refined Resources hav...
# 1                    NaN                                                NaN
# 1           95000-115000                                                ...
# ...                  ...                                                ...
# 1                    NaN                                                NaN
# 1                    NaN                                                NaN
# 1                    NaN                                                NaN
# 1                    NaN                                                NaN
# 1                    NaN  Anthony Warren is a Marketing and Advertising ...
#
#                                                   description  \
# fraudulent
# 1           IC&amp;E Technician | Bakersfield, CA Mt. Poso...
# 1           The group has raised a fund for the purchase o...
# 1           Technician Instrument &amp; ControlsLocation D...
# 1                                             Sales Executive
# 1           IC&amp;E Technician | Bakersfield, CA Mt. Poso...
# ...                                                       ...
# 1           Student Positions Part-Time and Full-Time.You ...
# 1           LEARN TO EARN AN EXECUTIVE LEVEL INCOMEFULL TR...
# 1           inFullMobile Sp. z o.o. is a mobile software d...
# 1           JOB DESCRIPTIONWe are seeking a full time payr...
# 1           earn $500 to $1000 a week as a mover.  Must ha...
#
#                                                  requirements  \
# fraudulent
# 1           QualificationsKnowledge, Skills &amp; Abilitie...
# 1                                                         NaN
# 1           JOB QUALIFICATIONS-Ability to understand proce...
# 1                                             Sales Executive
# 1            QualificationsKnowledge, Skills &amp; Abiliti...
# ...                                                       ...
# 1                                                         NaN
# 1           What You Can Do. • Have the potential to earn ...
# 1           • A proven track record in Android / JAVA proj...
# 1           JOB REQUIREMENTS•    High school diploma or eq...
# 1                    Good liftflexibile schedulegeat attitude
#
#                                                      benefits  telecommuting  \
# fraudulent
# 1           BENEFITSWhat is offered:Competitive compensati...              0
# 1                                                         NaN              0
# 1           we are a team of almost 8,000 employees who he...              0
# 1                                             Sales Executive              0
# 1           BENEFITSWhat is offered:Competitive compensati...              0
# ...                                                       ...            ...
# 1                                                         NaN              0
# 1           Who We Are We are a Global Leadership Developm...              0
# 1           attractive salary (adequate to the candidate s...              0
# 1           We offer a competitive salary and benefits pac...              0
# 1                                                         NaN              0
#
#             has_company_logo  has_questions employment_type  \
# fraudulent
# 1                          1              1       Full-time
# 1                          0              0             NaN
# 1                          1              1       Full-time
# 1                          0              0             NaN
# 1                          1              1       Full-time
# ...                      ...            ...             ...
# 1                          0              0       Part-time
# 1                          0              1             NaN
# 1                          0              0             NaN
# 1                          0              0       Full-time
# 1                          1              0             NaN
#
#            required_experience         required_education  \
# fraudulent
# 1             Mid-Senior level  High School or equivalent
# 1                          NaN                        NaN
# 1             Mid-Senior level              Certification
# 1                          NaN                        NaN
# 1             Mid-Senior level  High School or equivalent
# ...                        ...                        ...
# 1                          NaN                        NaN
# 1                          NaN                        NaN
# 1                          NaN                        NaN
# 1                          NaN                        NaN
# 1                          NaN                        NaN
#
#                                        industry             function
# fraudulent
# 1                                  Oil & Energy                Other
# 1                                           NaN                  NaN
# 1           Electrical/Electronic Manufacturing                Other
# 1                                           NaN                Sales
# 1                                  Oil & Energy                Other
# ...                                         ...                  ...
# 1                                           NaN                  NaN
# 1                                           NaN                  NaN
# 1                                           NaN                  NaN
# 1                             Apparel & Fashion  Accounting/Auditing
# 1                                           NaN                  NaN
#
# [866 rows x 17 columns]

# %%
#Create dict to collect word count
word_count = {}
#Count words in fake job postings
for description in fake_jobs['description']:
 for word in str(description).split():
    if word_count.get(word, 0) != 0:
         word_count[word] += 1  
#         print(word_count[word])
    else:
         word_count[word] = 1
#         print(word_count[word])


#Create dataframe
data_items = sorted(word_count.items(), key=lambda kv: kv[1], reverse=True)
data_list = list(data_items)
word_count_pd = pd.DataFrame(data_list,columns=["word","counter"])
print(len(word_count_pd))
#Limit size of words to analyze
word_count_pd.drop(word_count_pd[word_count_pd['word'][:].str.len() < 4].index, inplace = True)
#drop prepositions and other not significant words
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'with'].index, inplace = True) 
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'that'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'from'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'have'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'your'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'this'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'their'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == '&amp;'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'will'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'This'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'more'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'into'].index, inplace = True)
word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'also'].index, inplace = True)
#word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'other'].index, inplace = True)
word_count_pd.to_csv("words_in_fake_posting.csv")

#word_count_pd
# Out:
# 15547

# %%
#Get only Real Posting records
if fake_jobs_pd.index.name != 'fraudulent':
   fake_jobs_pd.set_index("fraudulent", inplace = True)
real_jobs_pd = fake_jobs_pd.loc[0]

# %%
#Create dict to collect word count for real job postings
word_count_real = {}
#Count words in fake job postings
for description in real_jobs_pd['description']:
 for word in str(description).split():
    if word_count_real.get(word, 0) != 0:
         word_count_real[word] += 1  
    else:
         word_count_real[word] = 1

#Create dataframe
data_items = sorted(word_count_real.items(), key=lambda kv: kv[1], reverse=True)
data_list = list(data_items)
word_count_real_pd = pd.DataFrame(data_list,columns=["word","counter"])
#Limit size of words to analyze
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'][:].str.len() < 4].index, inplace = True)
#drop prepositions and other not significant words
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'with'].index, inplace = True) 
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'that'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'from'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'have'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'your'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'this'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'their'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == '&amp;'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'will'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'This'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'more'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'into'].index, inplace = True)
word_count_real_pd.drop(word_count_real_pd[word_count_real_pd['word'] == 'also'].index, inplace = True)
#word_count_pd.drop(word_count_pd[word_count_pd['word'] == 'other'].index, inplace = True)
type(word_count_real_pd)
#word_count_real_pd.to_csv("words_in_real_posting.csv")
# Out:
# pandas.core.frame.DataFrame

# %%
fake_words_to_check = word_count_pd.merge(word_count_real_pd, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
fake_words_to_check= fake_words_to_check[0:50]
fake_words_to_check['weight']=fake_words_to_check['counter']/fake_words_to_check['counter'].sum()
fake_words_to_check.head()
fake_words_to_check.set_index = ["word"]

# %%
#Check possible fake job postings in the Data Science file
#The idea is to sum the % of fake_words_to_check in the description.
#The posting will be considered fake if the sum is over 0.5%
#perc_fake= pd.DataFrame(["Job_title",'city', 'state', 'country',
#                                     'Category','Job_description','job_type'])
perc_fake= pd.DataFrame(["Word"])

#fake_words_to_check = {}
#Count words in Data Science job postings
for description in ds_jobs_pd['job_description']:
 for word in str(description).split():
     if word == 'work':
        print(f"karaka",word)
     if fake_words_to_check.loc(word):

         #perc_fake[word] += fake_words_to_check['weight']
         #perc_fake[word] = "bla"
           print(word)
            
#     print(f"sdfdsf ", perc_fake, fake_words_to_check.get(word,0),word)


#df.loc[df['column_name'] == some_value]
 #if perc_fake[word] > 0.5:
 #       ds_fake_jobs_pd = ds_jobs_pd["Job_title",'city', 'state', 'country',
 #                                    'Category','Job_description','job_type']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-040790d0e144> in <module>
#      12      if word == 'work':
#      13         print(f"karaka",word)
# ---> 14      if fake_words_to_check.loc(word):
#      15
#      16          #perc_fake[word] += fake_words_to_check['weight']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     110
#     111         if axis is not None:
# --> 112             axis = self.obj._get_axis_number(axis)
#     113         new_self.axis = axis
#     114         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named Read for object type <class 'pandas.core.frame.DataFrame'>

# %%
len(perc_fake)
# Out:
# 1
